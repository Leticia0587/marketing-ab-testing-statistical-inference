# %% [markdown]
# # Teste de Hipótese — Experimento A/B: Campanha de Marketing Digital
#
# **Autora:** Leticia de Araujo
# **Pré-requisito:** `01_exploratory_analysis.ipynb`
# **Objetivo:** Testar formalmente se o anúncio digital aumentou causalmente a taxa de conversão
#
# ---

# %% [markdown]
# ## 1. Contexto Estatístico
#
# A análise exploratória do notebook 01 revelou:
# - Nenhum problema de qualidade dos dados
# - Evidência formal de randomização adequada (testes qui-quadrado aprovados)
# - Diferença preliminar de conversão de +0,77 p.p. (ad vs psa)
#
# Este notebook responde à pergunta central: **essa diferença é estatisticamente significativa e qual é sua magnitude prática?**
#
# Aplicamos um **teste Z unilateral para duas proporções** com α = 5%.

# %% [markdown]
# ---
# ## 2. Configuração do Ambiente

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mticker
from scipy.stats import norm
from statsmodels.stats.power import NormalIndPower

plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.float_format', '{:.6f}'.format)

# %%
df = pd.read_csv('../data/marketing_AB.csv').drop(columns=['Unnamed: 0'])

resumo = df.groupby('test group')['converted'].agg(n='count', conversoes='sum')
resumo['taxa_conversao'] = resumo['conversoes'] / resumo['n']

n_ad      = resumo.loc['ad',  'n']
n_psa     = resumo.loc['psa', 'n']
conv_ad   = resumo.loc['ad',  'conversoes']
conv_psa  = resumo.loc['psa', 'conversoes']
p_ad      = resumo.loc['ad',  'taxa_conversao']
p_psa     = resumo.loc['psa', 'taxa_conversao']

print('Dataset carregado com sucesso.')
print(resumo)
# Out:
# Dataset carregado com sucesso.
#                  n  conversoes  taxa_conversao
# test group
# ad          564577       14423        0.025547
# psa          23524         420        0.017854

# %% [markdown]
# ---
# ## 3. Formulação das Hipóteses
#
# ### Hipóteses Formais
#
# | Símbolo | Enunciado |
# |---------|----------|
# | **H₀** | p_ad ≤ p_psa — o anúncio não aumenta a conversão |
# | **H₁** | p_ad > p_psa — o anúncio aumenta a conversão |
# | **α**  | 0,05 (nível de significância de 5%) |
# | **Teste** | Teste Z unilateral (direita) para duas proporções |
# | **z crítico** | 1,645 |

# %% [markdown]
# ---
# ## 4. Estatísticas do Teste

# %% [markdown]
# ### 4.1 Proporção Combinada (Pooled)
#
# Sob H₀ assumimos que p_ad = p_psa = p_pool. Estimamos essa proporção comum combinando as duas amostras.

# %%
p_pool = (conv_ad + conv_psa) / (n_ad + n_psa)
print(f'Proporção combinada: p_pool = {p_pool:.6f}')
# Out:
# Proporção combinada: p_pool = 0.025239

# %% [markdown]
# ### 4.2 Erro Padrão

# %%
erro_padrao = np.sqrt(p_pool * (1 - p_pool) * (1/n_ad + 1/n_psa))
print(f'Erro padrão: EP = {erro_padrao:.8f}')
# Out:
# Erro padrão: EP = 0.00104374

# %% [markdown]
# ### 4.3 Estatística Z

# %%
z_stat = (p_ad - p_psa) / erro_padrao
print(f'Estatística Z: z = {z_stat:.4f}')
# Out:
# Estatística Z: z = 7.3701

# %% [markdown]
# ### 4.4 Valor Crítico e P-valor (Unilateral)

# %%
alpha       = 0.05
z_critico   = norm.ppf(1 - alpha)        # 1,6449 para α=0,05 unilateral
p_valor     = 1 - norm.cdf(z_stat)       # unilateral: área à DIREITA de z_stat

print(f'Valor crítico z_crit = {z_critico:.4f}')
print(f'P-valor (unilateral) = {p_valor:.2e}')
print()

rejeita_h0 = z_stat > z_critico
if rejeita_h0:
    print(f'z = {z_stat:.4f} > z_crit = {z_critico:.4f}  →  REJEITAMOS H₀')
    print(f'p = {p_valor:.2e} < α = {alpha}  →  resultado estatisticamente significativo')
else:
    print(f'z = {z_stat:.4f} ≤ z_crit = {z_critico:.4f}  →  NÃO REJEITAMOS H₀')
# Out:
# Valor crítico z_crit = 1.6449
# P-valor (unilateral) = 8.53e-14
#
# z = 7.3701 > z_crit = 1.6449  →  REJEITAMOS H₀
# p = 8.53e-14 < α = 0.05  →  resultado estatisticamente significativo

# %% [markdown]
# ---
# ## 5. Intervalo de Confiança

# %%
# EP não combinado para o IC da diferença (estimamos a diferença, não testamos sob H0)
ep_diferenca = np.sqrt(
    (p_ad  * (1 - p_ad)  / n_ad) +
    (p_psa * (1 - p_psa) / n_psa)
)

diferenca = p_ad - p_psa

# IC bilateral 95% para fins de comunicação
ic_inferior_95 = diferenca - 1.96 * ep_diferenca
ic_superior_95 = diferenca + 1.96 * ep_diferenca

# Limite inferior unilateral 95% (estimativa conservadora mais baixa)
ic_inferior_unilateral = diferenca - z_critico * ep_diferenca

print('INTERVALOS DE CONFIANÇA PARA O LIFT (p_ad - p_psa)')
print(f'  Estimativa pontual:          +{diferenca:.4f} (+{diferenca:.2%} p.p.)')
print(f'  IC 95% bilateral:            [{ic_inferior_95:.4f}, {ic_superior_95:.4f}]')
print(f'  IC 95% unilateral (inferior): [{ic_inferior_unilateral:.4f}, ∞)')
print()
print('Interpretação: temos 95% de confiança de que o lift verdadeiro é')
print(f'de pelo menos +{ic_inferior_unilateral:.4f} ({ic_inferior_unilateral:.2%} p.p.).')
print()
if ic_inferior_95 > 0:
    print('O IC bilateral 95% exclui zero — o lift é significativo')
    print('mesmo sob o critério bilateral mais conservador.')
# Out:
# INTERVALOS DE CONFIANÇA PARA O LIFT (p_ad - p_psa)
#   Estimativa pontual:          +0.0077 (+0.77% p.p.)
#   IC 95% bilateral:            [0.0060, 0.0094]
#   IC 95% unilateral (inferior): [0.0062, ∞)
#
# Interpretação: temos 95% de confiança de que o lift verdadeiro é
# de pelo menos +0.0062 (0.62% p.p.).
#
# O IC bilateral 95% exclui zero — o lift é significativo
# mesmo sob o critério bilateral mais conservador.

# %% [markdown]
# ---
# ## 6. Tamanho do Efeito — Cohen's h
#
# Significância estatística responde "isso é real?" não responde "quão grande é?"
#
# Com n > 500.000, até diferenças negligenciáveis atingem significância. O Cohen's h fornece uma medida do tamanho do efeito independente do tamanho amostral.
#
# | Cohen's h | Magnitude |
# |-----------|----------|
# | < 0,20    | Pequeno  |
# | 0,20–0,50 | Médio    |
# | > 0,50    | Grande   |

# %%
phi_ad    = 2 * np.arcsin(np.sqrt(p_ad))
phi_psa   = 2 * np.arcsin(np.sqrt(p_psa))
cohens_h  = abs(phi_ad - phi_psa)

if   cohens_h < 0.20: magnitude = 'Pequeno'
elif cohens_h < 0.50: magnitude = 'Médio'
else:                 magnitude = 'Grande'

print(f"Cohen's h = {cohens_h:.4f}  →  Efeito {magnitude}")
print()
print('Interpretação crítica:')
print('  O efeito é estatisticamente robusto (z = 7,37, p ≈ 0), mas a')
print('  magnitude absoluta é pequena. Isso é esperado em experimentos de')
print('  taxa de conversão com amostras muito grandes.')
print()
print("  Cohen's h pequeno NÃO significa que o resultado é irrelevante.")
print('  Em escala (milhões de usuários), até +0,77 p.p. gera milhares de')
print('  conversões adicionais. Veja a Seção 8.')
# Out:
# Cohen's h = 0.0530  →  Efeito Pequeno
#
# Interpretação crítica:
#   O efeito é estatisticamente robusto (z = 7,37, p ≈ 0), mas a
#   magnitude absoluta é pequena. Isso é esperado em experimentos de
#   taxa de conversão com amostras muito grandes.
#
#   Cohen's h pequeno NÃO significa que o resultado é irrelevante.
#   Em escala (milhões de usuários), até +0,77 p.p. gera milhares de
#   conversões adicionais. Veja a Seção 8.

# %% [markdown]
# ---
# ## 7. Análise de Poder Estatístico (Post-Hoc)
#
# A análise de poder responde: *"Dada nossa amostra, quão confiantes estamos de que detectaríamos o efeito real se ele existisse?"*
#
# - **Poder estatístico (1 - β):** probabilidade de rejeitar H₀ quando H₁ é verdadeira
# - **Erro tipo II (β):** probabilidade de não detectar um efeito real
# - Padrão da indústria: poder de 80% (β = 20%)

# %%
analise_poder = NormalIndPower()

# Razão de tamanho entre os grupos para análise de amostras desiguais
razao = n_ad / n_psa

poder_alcancado = analise_poder.power(
    effect_size = cohens_h,
    nobs1       = n_psa,
    alpha       = alpha,
    ratio       = razao,
    alternative = 'larger'
)

print('ANÁLISE DE PODER ESTATÍSTICO (POST-HOC)')
print('=' * 50)
print(f"  Tamanho do efeito (Cohen's h): {cohens_h:.4f}")
print(f"  n_psa (grupo controle):        {n_psa:,}")
print(f"  n_ad  (grupo tratamento):      {n_ad:,}")
print(f"  Razão n_ad/n_psa:              {razao:.1f}")
print(f"  Alpha (unilateral):            {alpha}")
print(f"  Poder alcançado (1-β):         {poder_alcancado:.4f} ({poder_alcancado:.1%})")
print()
if poder_alcancado >= 0.80:
    print(f'  RESULTADO: Poder = {poder_alcancado:.1%} ≥ 80% — poder adequado.')
    print('  A amostra é suficientemente grande para detectar esse efeito com confiança.')
    print('  Risco de Erro Tipo II (não detectar efeito real): mínimo.')
else:
    print(f'  RESULTADO: Poder = {poder_alcancado:.1%} < 80% — teste subdimensionado.')
    print('  Interprete resultados nulos com cautela — Erro Tipo II é um risco.')
# Out:
# ANÁLISE DE PODER ESTATÍSTICO (POST-HOC)
# ...
#   Tamanho do efeito (Cohen's h): 0.0530
#   n_psa (grupo controle):        23,524
#   n_ad  (grupo tratamento):      564,577
#   Razão n_ad/n_psa:              24.0
#   Alpha (unilateral):            0.05
#   Poder alcançado (1-β):         1.0000 (100.0%)
#
#   RESULTADO: Poder = 100.0% ≥ 80% — poder adequado.
#   A amostra é suficientemente grande para detectar esse efeito com confiança.
#   Risco de Erro Tipo II (não detectar efeito real): mínimo.

# %%
# Tamanho mínimo de amostra para 80% de poder em design BALANCEADO
n_minimo_balanceado = analise_poder.solve_power(
    effect_size = cohens_h,
    alpha       = alpha,
    power       = 0.80,
    ratio       = 1.0,
    alternative = 'larger'
)

print('TAMANHO MÍNIMO DE AMOSTRA (design balanceado 50/50, 80% de poder)')
print(f"  Necessário por grupo:  {int(np.ceil(n_minimo_balanceado)):,}")
print(f"  Total necessário:      {2 * int(np.ceil(n_minimo_balanceado)):,}")
print(f"  Total real utilizado:  {n_ad + n_psa:,}")
print()
print('  O dataset está massivamente superdimensionado.')
print('  Na prática, um experimento muito menor já seria suficiente para detectar esse efeito.')
# Out:
# TAMANHO MÍNIMO DE AMOSTRA (design balanceado 50/50, 80% de poder)
#   Necessário por grupo:  4,402
#   Total necessário:      8,804
#   Total real utilizado:  588,101
#
#   O dataset está massivamente superdimensionado.
#   Na prática, um experimento muito menor já seria suficiente para detectar esse efeito.

# %%
# Curva de poder: como o poder cresce com n_psa sob o efeito observado
n_range     = np.linspace(100, 30000, 300)
curva_poder = [analise_poder.power(cohens_h, n, alpha, ratio=razao, alternative='larger')
               for n in n_range]

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(n_range, curva_poder, color='#2196F3', linewidth=2)
ax.axhline(0.80, color='#FF5722', linestyle='--', linewidth=1.5,
           label='Limiar de 80% de poder')
ax.axvline(n_minimo_balanceado, color='gray', linestyle=':', linewidth=1.5,
           label=f'n mínimo (balanceado): {int(np.ceil(n_minimo_balanceado)):,}')
ax.axvline(n_psa, color='#4CAF50', linestyle='-', linewidth=1.5,
           label=f'n_psa real: {n_psa:,}')

ax.set_title("Curva de Poder: Poder Alcançado vs. Tamanho do Grupo Controle\n(Cohen's h = {:.4f}, α = 0,05, unilateral)".format(cohens_h),
             fontsize=12, fontweight='bold')
ax.set_xlabel('Tamanho do Grupo Controle (n_psa)', fontsize=11)
ax.set_ylabel('Poder Estatístico (1 - β)', fontsize=11)
ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1, decimals=0))
ax.legend(fontsize=10)
ax.set_ylim(0, 1.05)

plt.tight_layout()
plt.savefig('../outputs/curva_poder.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## 8. Impacto de Negócio
#
# Significância estatística isolada não justifica decisões de negócio. É preciso traduzir os resultados em termos financeiros acionáveis para os tomadores de decisão.
#
# > **Nota:** Os valores de receita abaixo são **cenários hipotéticos**, pois este dataset não contém dados de receita. Eles ilustram como os resultados estatísticos devem ser apresentados a gestores e executivos.

# %%
lift_absoluto = p_ad - p_psa

cenarios_alcance = [
    ('100 mil usuários expostos',  100_000),
    ('500 mil usuários expostos',  500_000),
    ('1 milhão de usuários',     1_000_000),
    ('10 milhões de usuários',  10_000_000),
]

print('PROJEÇÕES DE IMPACTO DE NEGÓCIO')
print('=' * 60)
print(f'Lift absoluto: +{lift_absoluto:.4f} (+{lift_absoluto:.2%} p.p.)')
print(f'Lift relativo: +{lift_absoluto/p_psa:.1%} sobre o baseline')
print()
print(f'{"Cenário":<30} {"Conversões Adicionais":>22}')
print('-' * 55)
for label, n in cenarios_alcance:
    conv_adicional = int(n * lift_absoluto)
    print(f'{label:<30} {conv_adicional:>22,}')

print()
print('IMPACTO FINANCEIRO (CENÁRIOS HIPOTÉTICOS)')
print('=' * 60)
receitas_por_conv = [50, 200, 1000]
n_ref = 1_000_000
conv_adicional_1m = int(n_ref * lift_absoluto)

print(f'\nBase: 1 milhão de usuários expostos → {conv_adicional_1m:,} conversões adicionais')
print()
for receita in receitas_por_conv:
    total = conv_adicional_1m * receita
    print(f'  R${receita:>6}/conversão  →  R${total:>12,.0f} de receita adicional')

print()
print('Regra de decisão:')
print('  A campanha é lucrativa quando:')
print('  Receita adicional > Custo total da campanha')
print('  (CPM × impressões) < (lift × receita por conversão × alcance)')
# Out:
# PROJEÇÕES DE IMPACTO DE NEGÓCIO
# ...
# Lift absoluto: +0.0077 (+0.77% p.p.)
# Lift relativo: +43.1% sobre o baseline
#
# Cenário                         Conversões Adicionais
# -------------------------------------------------------
# 100 mil usuários expostos                         769
# 500 mil usuários expostos                       3,846
# 1 milhão de usuários                            7,692
# 10 milhões de usuários                         76,924
#
# IMPACTO FINANCEIRO (CENÁRIOS HIPOTÉTICOS)
# ...
#
# Base: 1 milhão de usuários expostos → 7,692 conversões adicionais
#
#   R$    50/conversão  →  R$     384,600 de receita adicional
#   R$   200/conversão  →  R$   1,538,400 de receita adicional
#   R$  1000/conversão  →  R$   7,692,000 de receita adicional
#
# Regra de decisão:
#   A campanha é lucrativa quando:
#   Receita adicional > Custo total da campanha
#   (CPM × impressões) < (lift × receita por conversão × alcance)

# %%
alcances    = np.logspace(4, 7, 100)
convs_adics = alcances * lift_absoluto

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(alcances / 1e6, convs_adics, color='#2196F3', linewidth=2.5)

for n_usuarios, label in [(100_000, '100K'), (1_000_000, '1M'), (10_000_000, '10M')]:
    conv = n_usuarios * lift_absoluto
    ax.scatter(n_usuarios/1e6, conv, zorder=5, s=80)
    ax.annotate(f'{label} usuários\n+{conv:,.0f} conv.',
                xy=(n_usuarios/1e6, conv), xytext=(10, 10),
                textcoords='offset points', fontsize=9)

ax.set_title('Conversões Adicionais Projetadas pela Campanha\n(baseado no lift observado de +{:.2%} p.p.)'.format(lift_absoluto),
             fontsize=12, fontweight='bold')
ax.set_xlabel('Alcance (milhões de usuários)', fontsize=11)
ax.set_ylabel('Conversões Adicionais', fontsize=11)
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:.1f}M'))

plt.tight_layout()
plt.savefig('../outputs/impacto_negocio.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## 9. Visualização Completa dos Resultados

# %%
grupos     = ['Anúncio (ad)', 'Controle (psa)']
taxas      = [p_ad, p_psa]
margens_ic = [
    1.96 * np.sqrt(p_ad  * (1 - p_ad)  / n_ad),
    1.96 * np.sqrt(p_psa * (1 - p_psa) / n_psa)
]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# --- Painel 1: Taxas de conversão com IC ---
barras = axes[0].bar(grupos, taxas, yerr=margens_ic,
                     color=['#2196F3', '#FF5722'], width=0.45,
                     capsize=8, error_kw={'linewidth': 2}, alpha=0.85)

for barra, taxa, ic in zip(barras, taxas, margens_ic):
    axes[0].text(barra.get_x() + barra.get_width() / 2,
                 barra.get_height() + ic + 0.0008,
                 f'{taxa:.2%}', ha='center', fontsize=12, fontweight='bold')

axes[0].axhline(p_psa, color='gray', linestyle='--', linewidth=1.2, alpha=0.7,
                label='Baseline controle')
axes[0].set_title('Taxa de Conversão por Grupo\n(IC 95% exibido)', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Taxa de Conversão')
axes[0].yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1, decimals=2))
axes[0].set_ylim(0, max(taxas) * 1.6)
axes[0].legend(fontsize=10)

# --- Painel 2: Distribuição Z com região de rejeição ---
x = np.linspace(-4, 10, 600)
y = norm.pdf(x)

axes[1].plot(x, y, 'k-', linewidth=2)
axes[1].fill_between(x, y, where=(x >= z_critico),
                     color='#FF5722', alpha=0.35, label=f'Região de rejeição (α={alpha})')
axes[1].fill_between(x, y, where=(x < z_critico),
                     color='#2196F3', alpha=0.15, label='Região de aceitação')

axes[1].axvline(z_stat, color='#1B5E20', linewidth=2.5,
                label=f'z observado = {z_stat:.2f}')
axes[1].axvline(z_critico, color='#FF5722', linewidth=2, linestyle='--',
                label=f'z crítico = {z_critico:.3f}')

axes[1].set_title(f'Teste Z Unilateral (α = {alpha})\nH₁: p_ad > p_psa',
                  fontsize=12, fontweight='bold')
axes[1].set_xlabel('Estatística Z', fontsize=11)
axes[1].set_ylabel('Densidade de Probabilidade', fontsize=11)
axes[1].legend(fontsize=9)
axes[1].set_xlim(-4, 10)
axes[1].annotate(f'z = {z_stat:.2f}\n(fora do eixo →)',
                 xy=(8, 0.02), fontsize=9, color='#1B5E20', fontweight='bold')

plt.suptitle('Resultados do Teste A/B — Campanha de Marketing Digital',
             fontsize=13, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig('../outputs/conversion_rate_by_group.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\letic\AppData\Local\Temp\ipykernel_16684\2638880870.py:54: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\letic\AppData\Local\Temp\ipykernel_16684\2638880870.py:55: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.savefig('../outputs/conversion_rate_by_group.png', dpi=150, bbox_inches='tight')
# c:\Users\letic\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ---
# ## 10. Resumo Completo dos Resultados

# %%
print('=' * 60)
print('TESTE A/B — RESUMO ESTATÍSTICO COMPLETO')
print('=' * 60)
print()
print('CONFIGURAÇÃO DO EXPERIMENTO')
print(f'  Grupo tratamento (ad):   n = {n_ad:,}')
print(f'  Grupo controle   (psa):  n = {n_psa:,}')
print(f'  Tipo de teste:           Teste Z unilateral (direita)')
print(f'  Nível de significância α: {alpha}')
print()
print('RESULTADOS')
print(f'  p_ad  (tratamento):      {p_ad:.4f} ({p_ad:.2%})')
print(f'  p_psa (controle):        {p_psa:.4f} ({p_psa:.2%})')
print(f'  Lift absoluto:           +{lift_absoluto:.4f} (+{lift_absoluto:.2%} p.p.)')
print(f'  Lift relativo:           +{lift_absoluto/p_psa:.1%}')
print(f'  IC 95% bilateral:        [{ic_inferior_95:.4f}, {ic_superior_95:.4f}]')
print()
print('TESTE ESTATÍSTICO')
print(f'  Estatística Z:           {z_stat:.4f}')
print(f'  Valor crítico:           {z_critico:.4f}')
print(f'  P-valor (unilateral):    {p_valor:.2e}')
print(f'  Decisão:                 {"REJEITAMOS H₀" if rejeita_h0 else "NÃO REJEITAMOS H₀"}')
print()
print('TAMANHO DO EFEITO E PODER')
print(f"  Cohen's h:               {cohens_h:.4f} ({magnitude})")
print(f'  Poder alcançado:         {poder_alcancado:.2%}')
print(f'  n mínimo (balanceado):   {int(np.ceil(n_minimo_balanceado)):,} por grupo')
print()
print('IMPACTO DE NEGÓCIO (por 1 milhão de usuários expostos)')
print(f'  Conversões adicionais:   +{int(1_000_000 * lift_absoluto):,}')
print()
print('CONCLUSÃO')
print('  Há forte evidência estatística (z=7,37, p≈1,7×10⁻¹³) de que o')
print('  anúncio digital aumenta a taxa de conversão em relação ao controle.')
print('  O lift de +0,77 p.p. é pequeno em termos de Cohen\'s h, mas gera')
print('  volume expressivo em escala. A decisão de veicular a campanha')
print('  deve considerar o custo por impressão e a receita por conversão.')
print('=' * 60)
# Out:
# ...
# TESTE A/B — RESUMO ESTATÍSTICO COMPLETO
# ...
#
# CONFIGURAÇÃO DO EXPERIMENTO
#   Grupo tratamento (ad):   n = 564,577
#   Grupo controle   (psa):  n = 23,524
#   Tipo de teste:           Teste Z unilateral (direita)
#   Nível de significância α: 0.05
#
# RESULTADOS
#   p_ad  (tratamento):      0.0255 (2.55%)
#   p_psa (controle):        0.0179 (1.79%)
#   Lift absoluto:           +0.0077 (+0.77% p.p.)
#   Lift relativo:           +43.1%
#   IC 95% bilateral:        [0.0060, 0.0094]
#
# TESTE ESTATÍSTICO
#   Estatística Z:           7.3701
#   Valor crítico:           1.6449
#   P-valor (unilateral):    8.53e-14
#   Decisão:                 REJEITAMOS H₀
#
# TAMANHO DO EFEITO E PODER
#   Cohen's h:               0.0530 (Pequeno)
#   Poder alcançado:         100.00%
#   n mínimo (balanceado):   4,402 por grupo
#
# IMPACTO DE NEGÓCIO (por 1 milhão de usuários expostos)
#   Conversões adicionais:   +7,692
#
# CONCLUSÃO
#   Há forte evidência estatística (z=7,37, p≈1,7×10⁻¹³) de que o
# ...
