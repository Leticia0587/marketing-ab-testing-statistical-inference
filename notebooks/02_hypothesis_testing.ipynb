# %% [markdown]
# # Teste de Hipótese — Avaliação Estatística do Experimento A/B

# %% [markdown]
# ## Contexto Estatístico
#
# Após a análise exploratória, foi observada uma diferença na taxa de conversão entre os grupos.
#
# Nesta etapa, realizamos um teste estatístico para avaliar se essa diferença pode ser atribuída ao acaso ou se há evidência de um efeito real do anúncio.

# %% [markdown]
# ## Formulação das Hipóteses
#
# ### Hipóteses
#
# H0 (Hipótese Nula): p_ad = p_psa
# A taxa de conversão é igual entre os grupos.
#
# H1 (Hipótese Alternativa): p_ad ≠ p_psa
# As taxas de conversão são diferentes.
#
# Será utilizado teste bilateral com nível de significância de 5%.

# %% [markdown]
# ## 3. Importação das Bibliotecas

# %%
# Importação das bibliotecas
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
df = pd.read_csv('../data/marketing_AB.csv')

# %% [markdown]
# ## 4. Definição das Variáveis

# %%
# Tamanhos das amostras e conversões — extraídos diretamente dos dados
summary = df.groupby('test group')['converted'].agg(
    count='count',
    conversions='sum'
)

n_ad   = summary.loc['ad',  'count']
n_psa  = summary.loc['psa', 'count']

conv_ad  = summary.loc['ad',  'conversions']
conv_psa = summary.loc['psa', 'conversions']

# Proporções observadas
p_ad  = conv_ad  / n_ad
p_psa = conv_psa / n_psa

p_ad, p_psa
# Out:
# (np.float64(0.025546559636683747), np.float64(0.01785410644448223))

# %% [markdown]
# ## 5. Proporção Combinada (Pooled)

# %%
p_pool = (conv_ad + conv_psa) / (n_ad + n_psa)
p_pool
# Out:
# np.float64(0.02523886203220195)

# %% [markdown]
# ## 6. Cálculo do Erro Padrão

# %%
standard_error = np.sqrt(
    p_pool * (1 - p_pool) * (1/n_ad + 1/n_psa)
)

standard_error
# Out:
# np.float64(0.0010437410649006525)

# %% [markdown]
# ## 7. Estatística Z

# %%
z_stat = (p_ad - p_psa) / standard_error
z_stat
# Out:
# np.float64(7.3700781265454145)

# %% [markdown]
# ## 8. Cálculo do p-value (Bilateral)

# %%
p_value = 2 * (1 - norm.cdf(abs(z_stat)))
p_value
# Out:
# np.float64(1.7053025658242404e-13)

# %% [markdown]
# ## 9. Intervalo de Confiança (95%)

# %%
se_diff = np.sqrt(
    (p_ad * (1 - p_ad) / n_ad) +
    (p_psa * (1 - p_psa) / n_psa)
)

diff = p_ad - p_psa

ci_lower = diff - 1.96 * se_diff
ci_upper = diff + 1.96 * se_diff

ci_lower, ci_upper
# Out:
# (np.float64(0.00595090043017032), np.float64(0.009434005954232714))

# %% [markdown]
# ### 9.1 Tamanho do Efeito — Cohen's h
#
# O p-valor indica se a diferença é real. Cohen's h indica o quão grande ela é.
#
# Com amostras na ordem de 500 mil observações, o poder estatístico é extremamente
# elevado — qualquer diferença, mesmo ínfima, tende a ser detectada. Por isso,
# avaliar a magnitude do efeito é tão importante quanto a significância.

# %%
## 9.1 Tamanho do Efeito — Cohen's h
import numpy as np

# Transformação arcseno (fórmula do Cohen's h)
phi_ad  = 2 * np.arcsin(np.sqrt(p_ad))
phi_psa = 2 * np.arcsin(np.sqrt(p_psa))

cohens_h = abs(phi_ad - phi_psa)

# Interpretação
if cohens_h < 0.2:
    magnitude = "pequeno"
elif cohens_h < 0.5:
    magnitude = "médio"
else:
    magnitude = "grande"

print(f"Cohen's h: {cohens_h:.4f}")
print(f"Magnitude do efeito: {magnitude}")
print()
print("Nota: com amostras grandes, efeitos pequenos tornam-se")
print("estatisticamente significativos. Cohen's h contextualiza")
print("a magnitude real da diferença observada.")
# Out:
# Cohen's h: 0.0530
# Magnitude do efeito: pequeno
#
# Nota: com amostras grandes, efeitos pequenos tornam-se
# estatisticamente significativos. Cohen's h contextualiza
# a magnitude real da diferença observada.

# %% [markdown]
# ## 10. Decisão Estatística

# %%
alpha = 0.05

if p_value < alpha:
    print("Rejeitamos H0: há evidência estatística de diferença entre os grupos.")
else:
    print("Não rejeitamos H0: não há evidência estatística suficiente.")
# Out:
# Rejeitamos H0: há evidência estatística de diferença entre os grupos.

# %% [markdown]
# ## 11. Visualização dos Resultados

# %%
grupos = ['Anúncio (ad)', 'Controle (psa)']
proporcoes = [p_ad, p_psa]
erros = [1.96 * np.sqrt(p_ad * (1 - p_ad) / n_ad),
         1.96 * np.sqrt(p_psa * (1 - p_psa) / n_psa)]

fig, ax = plt.subplots(figsize=(8, 5))

cores = ['#2ecc71', '#e74c3c']
bars = ax.bar(grupos, proporcoes, color=cores, width=0.4,
              yerr=erros, capsize=8, error_kw={'linewidth': 2})

ax.set_title('Taxa de Conversão por Grupo com Intervalo de Confiança (95%)',
             fontsize=13, pad=15)
ax.set_ylabel('Taxa de Conversão', fontsize=11)
ax.set_ylim(0, max(proporcoes) * 1.5)

for bar, prop in zip(bars, proporcoes):
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() + 0.0015,
            f'{prop:.2%}',
            ha='center', va='bottom', fontsize=11, fontweight='bold')

ax.axhline(y=p_psa, color='gray', linestyle='--', linewidth=1, alpha=0.6,
           label='Baseline (psa)')
ax.legend(fontsize=10)

plt.tight_layout()
plt.savefig('../outputs/conversion_rate_by_group.png', dpi=150)
plt.show()

# %% [markdown]
# ## Conclusão do Teste de Hipótese
#
# O teste Z para duas proporções resultou em uma estatística Z de 7,37 e p-value inferior a 0,05, indicando evidência estatística robusta para rejeitar a hipótese nula de igualdade entre as taxas de conversão.
#
# Portanto, há evidência de que a taxa de conversão do grupo exposto ao anúncio é estatisticamente superior à do grupo controle.
#
# A diferença absoluta observada foi de aproximadamente 0,77 ponto percentual, representando um aumento relativo de cerca de 43%.
#
# Embora a significância estatística seja elevada, é importante avaliar a magnitude do efeito sob a perspectiva de negócio, considerando custo da campanha e impacto financeiro esperado.
